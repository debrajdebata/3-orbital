# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
cols = [p['color'] for p in plt.rcParams['axes.prop_cycle']]
plt.rc('text.latex', preamble=r'\usepackage{amsmath}\usepackage{braket}\usepackage{nicefrac}')
plt.rcParams.update({'font.size': 30,
                     'figure.figsize': (11,7),
                     'axes.facecolor': 'white',
                     'axes.edgecolor': 'lightgray',
                     "figure.autolayout": 'True',
                     'axes.xmargin': 0.03,
                     'axes.ymargin': 0.05,
                     'axes.grid': False,
                     'axes.linewidth': 5,
                     'lines.markersize': 10,
                     'text.usetex': True,
                     'lines.linewidth': 8,
                     "legend.frameon": True,
                     "legend.framealpha": 0.7,
                     "legend.handletextpad": 1,
                     "legend.edgecolor": "gray",
                     "legend.handlelength": 1,
                     "legend.labelspacing": 0,
                     "legend.columnspacing": 1,
                     "legend.fontsize": 35,
                    })
linestyles = ["-", "--", ":"]

g = np.linspace(0,4,40)
ev_1 = 0.5*(1+np.sqrt(1 + 4*g**2))
ev_2 = 0.5*(1-np.sqrt(1 + 4*g**2))
ev_3 = 0.5*(3 + np.sqrt(1+ 8*g**2))
ev_4 = 0.5*(3 - np.sqrt(1+ 8*g**2))
plt.plot(g,ev_1,'-',color='c')
plt.plot(g,ev_2,'--',color='b')
plt.plot(g,ev_3,'*',color = 'y')
plt.plot(g,ev_4,'-*',color = 'g')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
cols = [p['color'] for p in plt.rcParams['axes.prop_cycle']]
plt.rc('text.latex', preamble=r'\usepackage{amsmath}\usepackage{braket}\usepackage{nicefrac}')
plt.rcParams.update({'font.size': 30,
                     'figure.figsize': (11,7),
                     'axes.facecolor': 'white',
                     'axes.edgecolor': 'lightgray',
                     "figure.autolayout": 'True',
                     'axes.xmargin': 0.03,
                     'axes.ymargin': 0.05,
                     'axes.grid': False,
                     'axes.linewidth': 5,
                     'lines.markersize': 10,
                     'text.usetex': True,
                     'lines.linewidth': 8,
                     "legend.frameon": True,
                     "legend.framealpha": 0.7,
                     "legend.handletextpad": 1,
                     "legend.edgecolor": "gray",
                     "legend.handlelength": 1,
                     "legend.labelspacing": 0,
                     "legend.columnspacing": 1,
                     "legend.fontsize": 35,
                    })
linestyles = ["-", "--", ":"]

g = np.linspace(0,10,40)
k =  g
ev_1 = 1 -(k/2)
ev_2 = 2 -(k/2)

ev_4 = 0.25 * ( - np.sqrt(16*g**2 + k**2 + 4*k +4) - k +2)

ev_6 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k +6)
plt.plot(g,ev_1,'-',color='c',label=r'-')
plt.plot(g,ev_2,'--',color='b',label=r'-')

plt.plot(g,ev_4,'-*',color = 'g',label=r'-')

plt.plot(g,ev_6,'-*',color = 'r',label=r'-')
plt.xlabel(r'$g$')
plt.ylabel('Eigenvalue')
plt.title('$k = g$')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
cols = [p['color'] for p in plt.rcParams['axes.prop_cycle']]
plt.rc('text.latex', preamble=r'\usepackage{amsmath}\usepackage{braket}\usepackage{nicefrac}')
plt.rcParams.update({'font.size': 30,
                     'figure.figsize': (11,7),
                     'axes.facecolor': 'white',
                     'axes.edgecolor': 'lightgray',
                     "figure.autolayout": 'True',
                     'axes.xmargin': 0.03,
                     'axes.ymargin': 0.05,
                     'axes.grid': False,
                     'axes.linewidth': 5,
                     'lines.markersize': 10,
                     'text.usetex': True,
                     'lines.linewidth': 8,
                     "legend.frameon": True,
                     "legend.framealpha": 0.7,
                     "legend.handletextpad": 1,
                     "legend.edgecolor": "gray",
                     "legend.handlelength": 1,
                     "legend.labelspacing": 0,
                     "legend.columnspacing": 1,
                     "legend.fontsize": 35,
                    })
linestyles = ["-", "--", ":"]

g = np.linspace(0,10,40)
k = g
ev_1 = -1 -(k/2)
ev_2 = -(k/2)
### up-0 and 0-up with 2
ev_3 = 0.25 * ( + np.sqrt(16*g**2 + k**2 + 4*k +4) - k -6)
ev_4 = 0.25 * ( - np.sqrt(16*g**2 + k**2 + 4*k +4) - k -6)
### up-0 and 0-up with 1
#ev_5 = 0.25 * ( + np.sqrt(16*g**2 + k**2 + 4*k +4) - k -2)
ev_6 = 0.25 * ( - np.sqrt(16*g**2 + k**2 + 4*k +4) - k -2)
### up-0 and 0-up with 0
ev_7 = 0.25 * ( + np.sqrt(16*g**2 + k**2 + 4*k +4) - k +2)
ev_8 = 0.25 * ( - np.sqrt(16*g**2 + k**2 + 4*k +4) - k +2)
### singlet
ev_9 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k -2)
#ev_10 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k +2)
#ev_11 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k +6)
#plt.plot(g,ev_1,'-',color='c',label=r'-')
#plt.plot(g,ev_2,'--',color='b',label=r'-')
#plt.plot(g,ev_3,'*',color = 'y',label=r'-')
plt.plot(g,ev_4,'-*',color = 'g',label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{2}$ ')
#plt.plot(g,ev_5,'*',color = 'm',label=r'-')
#plt.plot(g,ev_6,'-*',color = 'r',label=r'-')
#plt.plot(g,ev_8,'--',color = 'r',label=r'-')
plt.plot(g,ev_9,'-',color = 'm',label=r' $(\ket{0,2} + \alpha \ket{SS})\otimes \ket{2}$ ')
#plt.plot(g,ev_10,'-',color = 'm',label=r'-')
#plt.plot(g,ev_11,'-',color = 'm',label=r'-')
plt.xlabel(r'$g$')
plt.ylabel('Eigenvalue')
plt.title('$k = g$')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
cols = [p['color'] for p in plt.rcParams['axes.prop_cycle']]
plt.rc('text.latex', preamble=r'\usepackage{amsmath}\usepackage{braket}\usepackage{nicefrac}')
plt.rcParams.update({'font.size': 30,
                     'figure.figsize': (11,7),
                     'axes.facecolor': 'white',
                     'axes.edgecolor': 'lightgray',
                     "figure.autolayout": 'True',
                     'axes.xmargin': 0.03,
                     'axes.ymargin': 0.05,
                     'axes.grid': False,
                     'axes.linewidth': 5,
                     'lines.markersize': 10,
                     'text.usetex': True,
                     'lines.linewidth': 8,
                     "legend.frameon": True,
                     "legend.framealpha": 0.7,
                     "legend.handletextpad": 1,
                     "legend.edgecolor": "gray",
                     "legend.handlelength": 1,
                     "legend.labelspacing": 0,
                     "legend.columnspacing": 1,
                     "legend.fontsize": 35,
                    })
linestyles = ["-", "--", ":"]

g = np.linspace(0,10,40)
k = 10* g
ev_1 = -1 -(k/2)
ev_2 = -(k/2)
### up-0 and 0-up with 2
ev_3 = 0.25 * ( + np.sqrt(16*g**2 + k**2 + 4*k +4) - k -6)
ev_4 = 0.25 * ( - np.sqrt(16*g**2 + k**2 + 4*k +4) - k -6)
### up-0 and 0-up with 1
#ev_5 = 0.25 * ( + np.sqrt(16*g**2 + k**2 + 4*k +4) - k -2)
ev_6 = 0.25 * ( - np.sqrt(16*g**2 + k**2 + 4*k +4) - k -2)
### up-0 and 0-up with 0
ev_7 = 0.25 * ( + np.sqrt(16*g**2 + k**2 + 4*k +4) - k +2)
ev_8 = 0.25 * ( - np.sqrt(16*g**2 + k**2 + 4*k +4) - k +2)
### singlet
ev_9 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k -2)
#ev_10 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k +2)
#ev_11 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k +6)
#plt.plot(g,ev_1,'-',color='c',label=r'-')
#plt.plot(g,ev_2,'--',color='b',label=r'-')
#plt.plot(g,ev_3,'*',color = 'y',label=r'-')
plt.plot(g,ev_4,'-*',color = 'g',label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{2}$ ')
#plt.plot(g,ev_5,'*',color = 'm',label=r'-')
#plt.plot(g,ev_6,'-*',color = 'r',label=r'-')
#plt.plot(g,ev_8,'--',color = 'r',label=r'-')
plt.plot(g,ev_9,'-',color = 'm',label=r' $(\ket{0,2} + \alpha \ket{SS})\otimes \ket{2}$ ')
#plt.plot(g,ev_10,'-',color = 'm',label=r'-')
#plt.plot(g,ev_11,'-',color = 'm',label=r'-')
plt.xlabel(r'$g$')
plt.ylabel('Eigenvalue')
plt.title('$k =10* g$')
plt.legend()
plt.show()

# %% [markdown]
# ## with U_b

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
cols = [p['color'] for p in plt.rcParams['axes.prop_cycle']]
plt.rc('text.latex', preamble=r'\usepackage{amsmath}\usepackage{braket}\usepackage{nicefrac}')
plt.rcParams.update({'font.size': 30,
                     'figure.figsize': (11,7),
                     'axes.facecolor': 'white',
                     'axes.edgecolor': 'lightgray',
                     "figure.autolayout": 'True',
                     'axes.xmargin': 0.03,
                     'axes.ymargin': 0.05,
                     'axes.grid': False,
                     'axes.linewidth': 5,
                     'lines.markersize': 10,
                     'text.usetex': True,
                     'lines.linewidth': 8,
                     "legend.frameon": True,
                     "legend.framealpha": 0.7,
                     "legend.handletextpad": 1,
                     "legend.edgecolor": "gray",
                     "legend.handlelength": 1,
                     "legend.labelspacing": 0,
                     "legend.columnspacing": 1,
                     "legend.fontsize": 35,
                    })
linestyles = ["-", "--", ":"]

g = np.linspace(0,10,40)
k =  1  ## U
h = -k ## U_b
### up-0 and 0-up with 2
ev_4 = 0.125 * ( - np.sqrt(64*g**2 + h**2 -4*h*k -8*h + 4*k**2 + 16*k +16) - h -2*k -12)

### up-0 and 0-up with up
ev_6 = 0.125 * ( - np.sqrt(64*g**2 + 9*h**2 -12*h*k -24*h + 4*k**2 +16*k +16) - 5*h -2*k -4)
### up-0 and 0-up with down
ev_8 = 0.125 * ( - np.sqrt(64*g**2 + (h +2*k +4)**2) - h -2*k -4)
### up-0 and 0-up with 0
ev_10 = 0.125 * ( - np.sqrt(64*g**2 + h**2 -4*h*k -8*h + 4*k**2 + 16*k +16) -h -2*k +4)
### singlet
#ev_9 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k -2)
#ev_10 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k +2)
#ev_11 = 0.25 * ( - np.sqrt(32*g**2 + k**2 + 4*k +4) - k +6)
#plt.plot(g,ev_1,'-',color='c',label=r'-')
#plt.plot(g,ev_2,'--',color='b',label=r'-')
#plt.plot(g,ev_3,'*',color = 'y',label=r'-')
plt.plot(g,ev_4,'-*',color = 'g',label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{2}$ ')
plt.plot(g,ev_6,'-*',color = 'c',label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{\sigma}$ ')
plt.plot(g,ev_8,'-*',color = 'y',label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{\bar{\sigma}}$ ')
plt.plot(g,ev_10,'-*',color = 'r',label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{0}$ ')
plt.xlabel(r'$g$')
plt.ylabel('Eigenvalue')
#plt.ylim(-50,0)
#plt.title('$k = g$')
plt.legend()
plt.show()

# %%
import numpy as np
from numpy.linalg import eig

a = 40
k = np.linspace(1,500,a)
h = -k
g = np.linspace(123,150,a)

e0 = []
e1 = []
e2 = []
e3 = []
e4 = []
e5 = []
e6 = []
e7 = []


for i in range(0,a,1) :
    ev_0 = [[2, g[i], -g[i]],[g[i], 1-k[i]/2-h[i]/4, 0],[-g[i], 0, 1-k[i]/2-h[i]]]
    w0,v0=linalg.eig(ev_0)
    idx = w0.argsort()[::1]   
    w0 = w0[idx]
    v0 = eigenVectors[:,idx]
    e0.append(w0[0])
    #print('E-value:', w0[0])
    #print('E-vector', v0)


    ev_1 = [[1-h[i]/4, g[i], -g[i]],[g[i], -k[i]/2, 0],[-g[i], 0, -k[i]/2-h[i]]]
    w1,v1=linalg.eig(ev_1)
    idx = w1.argsort()[::1]   
    w1 = w1[idx]
    v1 = eigenVectors[:,idx]
    e1.append(w1[0])
    #print('E-value:', w1[0])
    #print('E-vector', v1)

    ev_2 = [[1-h[i]/4, g[i], -g[i]],[g[i], -k[i]/2-h[i], 0],[-g[i], 0, -k[i]/2]]
    w2,v2=linalg.eig(ev_2)
    idx = w2.argsort()[::1]   
    w2 = w2[idx]
    v1 = eigenVectors[:,idx]
    e2.append(w2[0])
    #print('E-value:', w2[0])
    #print('E-vector', v2)

    ev_3 = [[0, g[i], -g[i]],[g[i], -k[i]/2-h[i]/4-1, 0],[-g[i], 0, -k[i]/2-h[i]/4-1]]
    w3,v3=linalg.eig(ev_3)
    idx = w3.argsort()[::1]   
    w3 = w3[idx]
    v3 = eigenVectors[:,idx]
    e3.append(w3[0])
    #print('E-value:', w3[0])
    #print('E-vector', v3)
    
    ev_4 = 0.125 * ( - np.sqrt(64*g[i]**2 + h[i]**2 -4*h[i]*k[i] -8*h[i] + 4*k[i]**2 + 16*k[i] +16) - h[i] -2*k[i] -12)
    e4.append(ev_4)
    
    ev_5 = 0.125 * ( - np.sqrt(64*g[i]**2 + 9*h[i]**2 -12*h[i]*k[i] -24*h[i] + 4*k[i]**2 +16*k[i] +16) - 5*h[i] -2*k[i] -4)
    e5.append(ev_5)
    
    ev_6 = 0.125 * ( - np.sqrt(64*g[i]**2 + (h[i] +2*k[i] +4)**2) - h[i] -2*k[i] -4)
    e6.append(ev_6)
    
    ev_7 = 0.125 * ( - np.sqrt(64*g[i]**2 + h[i]**2 -4*h[i]*k[i] -8*h[i] + 4*k[i]**2 + 16*k[i] +16) -h[i] -2*k[i] +4)
    e7.append(ev_7)
    
plt.plot(g,e0,label=r'$(\ket{0,2} + \alpha \ket{\uparrow,\downarrow} + \beta \ket{\downarrow,\uparrow})\otimes \ket{0}$ ')
plt.plot(g,e1,label=r'$(\ket{0,2} + \alpha \ket{\uparrow,\downarrow} + \beta \ket{\downarrow,\uparrow})\otimes \ket{\sigma}$' )
plt.plot(g,e2,'--',label=r'$(\ket{0,2} + \alpha \ket{\uparrow,\downarrow} + \beta \ket{\downarrow,\uparrow})\otimes \ket{\bar{\sigma}}$ ')
plt.plot(g,e3,label=r'$(\ket{0,2} + \alpha \ket{\uparrow,\downarrow} + \beta \ket{\downarrow,\uparrow})\otimes \ket{2}$ ')
plt.plot(g,e4,label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{2}$ ')
plt.plot(g,e5,label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{\sigma}$ ')
plt.plot(g,e6,label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{\bar{\sigma}}$ ')
plt.plot(g,e7,label=r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{0}$ ')
plt.xlabel(r'$g$')
plt.ylabel('Eigenvalue')
#plt.ylim(-50,0)
#plt.title('$k = g$')
plt.legend(fontsize='small')
plt.show()

# %%
import numpy as np
import numpy.linalg as linalg

A = [[1,2,3],[4,5,6],[7,8,9]]
eigenValues, eigenVectors = linalg.eig(A)
print(eigenValues)
print(eigenVectors)
idx = eigenValues.argsort()[::1]   
eigenValues = eigenValues[idx]
eigenVectors = eigenVectors[:,idx]
print(eigenValues)
print(eigenVectors)
# Out:
# [ 1.61168440e+01 -1.11684397e+00 -3.38433605e-16]
# [[-0.23197069 -0.78583024  0.40824829]
#  [-0.52532209 -0.08675134 -0.81649658]
#  [-0.8186735   0.61232756  0.40824829]]
# [-1.11684397e+00 -3.38433605e-16  1.61168440e+01]
# [[-0.78583024  0.40824829 -0.23197069]
#  [-0.08675134 -0.81649658 -0.52532209]
#  [ 0.61232756  0.40824829 -0.8186735 ]]

# %%
import numpy as np
from numpy.linalg import eig
from matplotlib import colors

frequency = 700
k = np.linspace(0,200,frequency)
h = -k
g = np.linspace(0,200,frequency)

e0 = []
e1 = []
e2 = []
e3 = []
e4 = []
e5 = []
e6 = []
e7 = []
flag_all = []

for i in range(0,frequency,1) :
    flag_all.append([])
    for j in range(0,frequency,1) :
        ev_0 = [[2, g[i], -g[i]],[g[i], 1-k[j]/2-h[j]/4, 0],[-g[i], 0, 1-k[j]/2-h[j]]]
        w0,v0=linalg.eigh(ev_0)
        idx = w0.argsort()[::1]   
        w0 = w0[idx]
        v0 = eigenVectors[:,idx]
        e0.append(w0[0])
        #print('E-value:', w0[0])
        #print('E-vector', v0)

        ev_1 = [[1-h[j]/4, g[i], -g[i]],[g[i], -k[j]/2, 0],[-g[i], 0, -k[j]/2-h[j]]]
        w1,v1=linalg.eigh(ev_1)
        idx = w1.argsort()[::1]   
        w1 = w1[idx]
        v1 = eigenVectors[:,idx]
        e1.append(w1[0])
        #print('E-value:', w1[0])
        #print('E-vector', v1)

        ev_2 = [[1-h[j]/4, g[i], -g[i]],[g[i], -k[j]/2-h[j], 0],[-g[i], 0, -k[j]/2]]
        w2,v2=linalg.eigh(ev_2)
        idx = w2.argsort()[::1]   
        w2 = w2[idx]
        v1 = eigenVectors[:,idx]
        e2.append(w2[0])
        #print('E-value:', w2[0])
        #print('E-vector', v2)

        ev_3 = [[0, g[i], -g[i]],[g[i], -k[j]/2-h[j]/4-1, 0],[-g[i], 0, -k[j]/2-h[j]/4-1]]
        w3,v3=linalg.eigh(ev_3)
        idx = w3.argsort()[::1]   
        w3 = w3[idx]
        v3 = eigenVectors[:,idx]
        e3.append(w3[0])
        #print('E-value:', w3[0])
        #print('E-vector', v3)

        ev_4 = 0.125 * ( - np.sqrt(64*g[i]**2 + h[j]**2 -4*h[j]*k[j] -8*h[j] + 4*k[j]**2 + 16*k[j] +16) - h[j] -2*k[j] -12)
        e4.append(ev_4)

        ev_5 = 0.125 * ( - np.sqrt(64*g[i]**2 + 9*h[j]**2 -12*h[j]*k[j] -24*h[j] + 4*k[j]**2 +16*k[j] +16) - 5*h[j] -2*k[j] -4)
        e5.append(ev_5)

        ev_6 = 0.125 * ( - np.sqrt(64*g[i]**2 + (h[j] +2*k[j] +4)**2) - h[j] -2*k[j] -4)
        e6.append(ev_6)

        ev_7 = 0.125 * ( - np.sqrt(64*g[i]**2 + h[j]**2 -4*h[j]*k[j] -8*h[j] + 4*k[j]**2 + 16*k[j] +16) -h[j] -2*k[j] +4)
        e7.append(ev_7)
        
        e_all = [w0[0], w1[0], w2[0], w3[0], ev_4, ev_5, ev_6, ev_7]
        
        if w0[0] == min(e_all):
            flag = 0
        elif w1[0] == min(e_all):
            flag = 1
        elif w2[0] == min(e_all):
            flag = 2
        elif w3[0] == min(e_all):
            flag = 3
        elif ev_4 == min(e_all):
            flag = 4
        elif ev_5 == min(e_all):
            flag = 5
        elif ev_6 == min(e_all):
            flag = 6
        elif ev_7 == min(e_all):
            flag = 7
        flag_all[-1].append(flag)

        
unique, counts = np.unique(flag_all, return_counts=True)
new_list = unique[np.where(counts > 1)]
 
print(new_list)
labels = [r'$(\ket{0,2} + \alpha \ket{\uparrow,\downarrow} + \beta \ket{\downarrow,\uparrow})\otimes \ket{0}$ ',
         r'$(\ket{0,2} + \alpha \ket{\uparrow,\downarrow} + \beta \ket{\downarrow,\uparrow})\otimes \ket{\sigma}$' ,
         r'$(\ket{0,2} + \alpha \ket{\uparrow,\downarrow} + \beta \ket{\downarrow,\uparrow})\otimes \ket{\bar{\sigma}}$', 
         r'$(\ket{0,2} + \alpha \ket{\uparrow,\downarrow} + \beta \ket{\downarrow,\uparrow})\otimes \ket{2}$',
         r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{2}$ ', 
         r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{\sigma}$ ',
         r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{\bar{\sigma}}$ ',
         r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{0}$ '
        ]
cmap = plt.cm.Dark2
#norm = colors.BoundaryNorm(np.arange(-0.5, 8, 1), cmap.N)
cmap_color = [0,2,5,7]
im1 = plt.imshow(flag_all, origin='lower', cmap=cmap, aspect = "auto",extent=(min(abs(h)), max(abs(h)), min(g), max(g)),interpolation="None")
for i,j in zip(new_list,cmap_color):
    plt.scatter([],[], color = cmap(j), label = labels[i])
plt.legend()
plt.ylabel('$V_2/t_{\perp}$')
plt.xlabel('$|U_b|/t_{\perp}$')
plt.title('Ground State Phase')
plt.show()
# Out:
# [1 2 3 4]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors

plt.style.use('ggplot')
cols = [p['color'] for p in plt.rcParams['axes.prop_cycle']]
plt.rc('text.latex', preamble=r'\usepackage{amsmath}\usepackage{braket}\usepackage{nicefrac}')
plt.rcParams.update({'font.size': 30,
                     'figure.figsize': (11,7),
                     'axes.facecolor': 'white',
                     'axes.edgecolor': 'lightgray',
                     "figure.autolayout": 'True',
                     'axes.xmargin': 0.03,
                     'axes.ymargin': 0.05,
                     'axes.grid': False,
                     'axes.linewidth': 5,
                     'lines.markersize': 10,
                     'text.usetex': True,
                     'lines.linewidth': 8,
                     "legend.frameon": True,
                     "legend.framealpha": 0.7,
                     "legend.handletextpad": 1,
                     "legend.edgecolor": "gray",
                     "legend.handlelength": 1,
                     "legend.labelspacing": 0,
                     "legend.columnspacing": 1,
                     "legend.fontsize": 35,
                    })
linestyles = ["-", "--", ":"]



frequency = 2000
k = np.linspace(0,200,frequency)  # k = U/t_{perp}
h = -k                            # h = U_b/t_{perp}
g = np.linspace(0,200,frequency)  # g = V2/t_{perp}

e0 = []
e1 = []
e2 = []
e3 = []
e4 = []
e5 = []
e6 = []
e7 = []
flag_all = []

for i in range(0,frequency,1) :
    flag_all.append([])
    for j in range(0,frequency,1) :
        ev_0 = [[2, g[i], -g[i]],[g[i], 1-k[j]/2-h[j]/4, 0],[-g[i], 0, 1-k[j]/2-h[j]]]
        w0,v0=np.linalg.eigh(ev_0)
        idx = w0.argsort()[::1]   
        w0 = w0[idx]
        v0 = v0[:,idx]
        e0.append(w0[0])
        #print('E-value:', w0[0])
        #print('E-vector', v0)

        ev_1 = [[1-h[j]/4, g[i], -g[i]],[g[i], -k[j]/2, 0],[-g[i], 0, -k[j]/2-h[j]]]
        w1,v1=np.linalg.eigh(ev_1)
        idx = w1.argsort()[::1]   
        w1 = w1[idx]
        v1 = v1[:,idx]
        e1.append(w1[0])
        #print('E-value:', np.round(w1[0],6))
        #print('E-vector', v1)

        ev_2 = [[1-h[j]/4, g[i], -g[i]],[g[i], -k[j]/2-h[j], 0],[-g[i], 0, -k[j]/2]]
        w2,v2=np.linalg.eigh(ev_2)
        idx = w2.argsort()[::1]   
        w2 = w2[idx]
        v1 = v2[:,idx]
        e2.append(w2[0])
        #print('E-value:', np.round(w2[0],6))
        #print('E-vector', v2)

        ev_3 = [[0, g[i], -g[i]],[g[i], -k[j]/2-h[j]/4-1, 0],[-g[i], 0, -k[j]/2-h[j]/4-1]]
        w3,v3=np.linalg.eigh(ev_3)
        idx = w3.argsort()[::1]   
        w3 = w3[idx]
        v3 = v3[:,idx]
        e3.append(w3[0])
        #print('E-value:', w3[0])
        #print('E-vector', v3)

        ev_4 = 0.125 * ( - np.sqrt(64*g[i]**2 + h[j]**2 -4*h[j]*k[j] -8*h[j] + 4*k[j]**2 + 16*k[j] +16) - h[j] -2*k[j] -12)
        e4.append(ev_4)

        ev_5 = 0.125 * ( - np.sqrt(64*g[i]**2 + 9*h[j]**2 -12*h[j]*k[j] -24*h[j] + 4*k[j]**2 +16*k[j] +16) - 5*h[j] -2*k[j] -4)
        e5.append(ev_5)

        ev_6 = 0.125 * ( - np.sqrt(64*g[i]**2 + (h[j] +2*k[j] +4)**2) - h[j] -2*k[j] -4)
        e6.append(ev_6)

        ev_7 = 0.125 * ( - np.sqrt(64*g[i]**2 + h[j]**2 -4*h[j]*k[j] -8*h[j] + 4*k[j]**2 + 16*k[j] +16) -h[j] -2*k[j] +4)
        e7.append(ev_7)
        
        e_all = [np.round(w0[0], 6), np.round(w1[0], 6), np.round(w2[0], 6),np.round(w3[0], 6), np.round(ev_4, 6), np.round(ev_5, 6), np.round(ev_6, 6), np.round(ev_7, 6)]
        
        if np.round(w0[0], 6) == min(e_all):
            flag = 0
        elif np.round(w1[0], 6) and np.round(w2[0], 6) == min(e_all):
            flag = 1
        elif np.round(w3[0], 6) == min(e_all):
            flag = 3
        elif np.round(ev_4, 6) == min(e_all):
            flag = 4
        elif np.round(ev_5, 6) == min(e_all):
            flag = 5
        elif np.round(ev_6, 6) == min(e_all):
            flag = 6
        elif np.round(ev_7, 6) == min(e_all):
            flag = 7
        flag_all[-1].append(flag)

        
unique, counts = np.unique(flag_all, return_counts=True)
new_list = unique[np.where(counts > 1)]
 
print(new_list)

labels = [r'$(\ket{0,2} + \alpha \ket{\uparrow,\downarrow} + \beta \ket{\downarrow,\uparrow})\otimes \ket{0}$ ',
         r'$(S_{tot}=2,S^z =0) \otimes (S_{tot}=1,S^z =1 \backslash  -1)$' ,
         r'$--$',  ## for flag 2 which is not present
         r'$(S_{tot}=2,S^z =0) \otimes(S_{tot}=2,S^z =0)$',
         r'$(S_{tot}=1,S^z =1 \backslash  -1)\otimes(S_{tot}=2,S^z =0)$ ', 
         r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{\sigma}$ ',
         r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{\bar{\sigma}}$ ',
         r'$(\ket{\sigma,0} + \alpha \ket{0,\sigma})\otimes \ket{0}$ '
        ]
cmap = plt.cm.Dark2
#norm = colors.BoundaryNorm(np.arange(-0.5, 8, 1), cmap.N)
cmap_color = [0,5,7]
im1 = plt.imshow(flag_all, origin='lower', cmap=cmap, aspect = "auto",extent=(min(abs(h)), max(abs(h)), min(g), max(g)),interpolation="None")
for i,j in zip(new_list,cmap_color):
    plt.scatter([],[], color = cmap(j), label = labels[i])
plt.legend(fontsize=24)
plt.ylabel('$V_2/t_{\perp}$')
plt.xlabel('$|U_b|/t_{\perp}$')
plt.title('Ground State Phase')
plt.savefig('Ground State Phase.pdf', bbox_inches='tight')
plt.savefig('Ground State Phase.png', bbox_inches='tight')
plt.show()
# Out:
# [1 3 4]
